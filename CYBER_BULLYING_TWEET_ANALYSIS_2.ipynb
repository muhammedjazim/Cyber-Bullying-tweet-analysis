# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammedjazim/Cyber-Bullying-tweet-analysis/blob/main/CYBER_BULLYING_TWEET_ANALYSIS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
#importing necessary libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import emoji
import string
import nltk
from sklearn.preprocessing import LabelEncoder
import pandas_profiling as pp

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from PIL import Image
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.tree import export_graphviz
import pickle

# %% [markdown]
# **Getting the data

# %%
data=pd.read_csv('/content/cyberbullying_tweets.csv')

# %% [markdown]
# # REVIEW OF THE DATA SET

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
data.head(10)
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# 5  @Raja5aab @Quickieleaks Yes, the test of god i...  not_cyberbullying
# 6  Itu sekolah ya bukan tempat bully! Ga jauh kay...  not_cyberbullying
# 7  Karma. I hope it bites Kat on the butt. She is...  not_cyberbullying
# 8       @stockputout everything but mostly my priest  not_cyberbullying
# 9  Rebecca Black Drops Out of School Due to Bully...  not_cyberbullying

# %%
data.sample(20)
# Out:
#                                               tweet_text   cyberbullying_type
# 5804    I cleaned my room now im doin my motherly duties    not_cyberbullying
# 12376  “I’m sorry I made jokes about touching little ...               gender
# 43089  Lmfaoo RT @gottdamm_jossi: Lol! RT @retrowill3...            ethnicity
# 47086  You need Jesus! RT @loveee_tdale “@tayyoung_: ...            ethnicity
# 45635  Fuck you bitch!!!! "@Colton_Zappe: Fuck that d...            ethnicity
# 25466                          @prpltnkr @Rosie not sure  other_cyberbullying
# 13842                    bitches get cut off everyday B                gender
# 17110  With all due respect. He’s not disagreeing wit...             religion
# 40569  Dumb fucking nigger spick whatever the fuck yo...            ethnicity
# 20671  Thank you to the other comment which mentions ...             religion
# 25765         @kencf0618 Being blocked isn't harassment.  other_cyberbullying
# 22964  It says that 1 muslim is enough for 10 kafir. ...             religion
# 19242  And, cohesive force for these loose gathering ...             religion
# 24766  People who use the word 'Feminazi' should be r...  other_cyberbullying
# 41940  To the nigger ridin a bike down joe hinton 2 t...            ethnicity
# 22724  Some idiots are still under the impression tha...             religion
# 20326  No she wasn't killed for being a muslim, you i...             religion
# 32395  I sometimes think back to some guy trying to b...                  age
# 43588  Over the past few generations of white parents...            ethnicity
# 22077  @LBC You bloody IDIOT. UNDER the RADAR COVER o...             religion

# %% [markdown]
# ## Checking for missing values in the data set

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %% [markdown]
# ### No null values found

# %%
#Shape of the data set or dimersions of the data set
print('The number of rows present: ',data.shape[0])
print('The number of columns present: ',data.shape[1])
# Out:
# The number of rows present:  47692
# The number of columns present:  2

# %%
#Columns/ attributes present in the data set
print('The different columns present in the data set is: ', data.columns)
# Out:
# The different columns present in the data set is:  Index(['tweet_text', 'cyberbullying_type'], dtype='object')

# %%
#Looking for different types of data present in the cyber bullying columns
data['cyberbullying_type'].unique()
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)

# %% [markdown]
# ### We can see that there are six distinct types of cyber bullying present in the columns. Let us look the count of different types of cyber bullying present.

# %%
#Count of different types of tweets in the data set
data['cyberbullying_type'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %% [markdown]
# #### It can be seen that there are almost equal number of distribution of different types of cyberbulling tweets in the data set.

# %% [markdown]
# # We will be renaming the columns for better understanding

# %%
data=data.rename(columns={'tweet_text':'Text', 'cyberbullying_type':'Sentiment'})

# %%
data.head()
# Out:
#                                                 Text          Sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# ##  In this part we are going to encode each type of cyber bullying type into a number ranging from 1 - 6

# %%
data['Sentiment'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: Sentiment, dtype: int64

# %%
#profile = pp.ProfileReport(data)
#profile.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## The encoding will be done as follows:
# #### 1.religion                          1
# #### 2.age                                 2
# #### 3.gender                           3
# #### 4.ethnicity                        4
# #### 5.not_cyberbullying        5
# #### 6.other_cyberbullying    6

# %%
labelencoder=LabelEncoder()

#data.drop('Encoded_Sentiment',inplace=True, axis=1)


data['Sentiment_encoded']=labelencoder.fit_transform(data['Sentiment'])
data.sample(15)
# Out:
#                                                     Text            Sentiment  \
# 11683  @Sidistic_ over gay and rape jokes? Bristol ca...               gender
# 27226  I still love you, tech workers. But if you liv...  other_cyberbullying
# 49     no one ever help.me like my bully @AlwaysVero_...    not_cyberbullying
# 5219   If we're at the bottom of the leaderboard, we'...    not_cyberbullying
# 27975  @jessimckenzi @zeynep @twitter @delbius @Tweet...  other_cyberbullying
# 11020  If the sassy models are really studying psycho...               gender
# 43409  @OutTheBandoo your a fucking ugly rat I'd fuck...            ethnicity
# 30854  ISIS: US 'being run by an idiot' https://t.co/...  other_cyberbullying
# 29917  And before you protest that you're *not* mad, ...  other_cyberbullying
# 42538  obama fuck u look what u did america get more ...            ethnicity
# 15702  @taenips @mxnira @pumpkey_ @dresstokilI @Drunk...               gender
# 1168   These outside challenges tend to separate the ...    not_cyberbullying
# 43555  Niger Innis Black Conservative says Melissa Ha...            ethnicity
# 41584  @RossWilliamKnig You poser dumb fuck. Suck my ...            ethnicity
# 8309   Black folks was making racist jokes, everyone ...               gender
#
#        Sentiment_encoded
# 11683                  2
# 27226                  4
# 49                     3
# 5219                   3
# 27975                  4
# 11020                  2
# 43409                  1
# 30854                  4
# 29917                  4
# 42538                  1
# 15702                  2
# 1168                   3
# 43555                  1
# 41584                  1
# 8309                   2

# %%
data[['Sentiment','Sentiment_encoded']].value_counts()
# Out:
# Sentiment            Sentiment_encoded
# religion             5                    7998
# age                  0                    7992
# gender               2                    7973
# ethnicity            1                    7961
# not_cyberbullying    3                    7945
# other_cyberbullying  4                    7823
# dtype: int64

# %%
stop_words=set(stopwords.words('english'))

# %% [markdown]
# # Preprocessing of text in the data set

# %% [markdown]
# ### Function to remove emojis

# %%
def strip_emoji(text):
    return emoji.replace_emoji(text,replace='')

# %% [markdown]
# ## Function to convert text to lower case, remove(/r, /n character), URLs, non-utf characters, number, punctuation, stopwords

# %%
def strip_all_entities(text):
    text = text.replace('\r','').replace('\n',' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]',r'', text)
    text = re.sub(r'(.)1+',r'1',text)
    text = re.sub('[0-9]+', '',text)
    stopchars = string.punctuation
    table = str.maketrans('', '',stopchars)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    return text

# %% [markdown]
# ## Functions to remove contractions

# %%
def decontract(text):
    text = re.sub(r"can\'t"," cannot", text)
    text = re.sub(r"n\'t"," not", text)
    text = re.sub(r"\'re"," are", text)
    text = re.sub(r"\'s"," is", text)
    text = re.sub(r"\'d"," would", text)
    text = re.sub(r"\'ll"," will", text)
    text = re.sub(r"\'t"," not", text)
    text = re.sub(r"\'ve"," have", text)
    text = re.sub(r"\'m"," am", text)
    return text

# %% [markdown]
# ## Function to clean hashtags

# %%
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hastags)\b)[\w-]+(?=(?:\s+#[w-]+)*\s*$)', tweet))
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet))
    return new_tweet2

# %% [markdown]
# ## Function to filter special character such as dollar and &

# %%
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if( '$' in word )  | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# %% [markdown]
# ## Function to remove multiple sequence spaces

# %%
def remove_mult_spaces(text):
    return re.sub("\s\s+", " ", text)

# %% [markdown]
# ## Function to apply stemming to words

# %%
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

# %% [markdown]
# ## Function to apply lemmatization to words

# %%
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

# %% [markdown]
# # A super function which will be used to preprocess text by applying all the above functions:

# %%
def preprocess(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    text = lemmatize(text)
    return text

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data['Cleaned_Text'] = data['Text'].apply(preprocess)

# %%
data.sample(10)
# Out:
#                                                     Text            Sentiment  \
# 22450  You guy's make THIS too easy, speaking of subu...             religion
# 43579  The ignorance. It’s been around for 101 years!...            ethnicity
# 15342  WOW TOP SHELF HUMOR @arabdizzle What's the poi...               gender
# 32378  My mom rap sheet speaks for itself and she use...                  age
# 40359  Hello Twitter. So my friend Marisol who is a p...            ethnicity
# 18812  New KeralaUS voices deep concern over rights a...             religion
# 35780  Yeah bc I’m hot, am getting my degrees, am kin...                  age
# 6072   RT @karina__hogan: @wedancedonce #mkr purposel...    not_cyberbullying
# 32363  A high school bully was murdered last year. Wh...                  age
# 28975  @whosamjohn Wym where??? I'm nothing like them...  other_cyberbullying
#
#        Sentiment_encoded                                       Cleaned_Text
# 22450                  5  guy make easi speak suburbia heyani idiot seen...
# 43579                  1  ignor around year lmao call negro hymn like ju...
# 15342                  2  wow top shelf humor point clean ladi mom siste...
# 32378                  0  mom rap sheet speak use stab mf tri bulli scho...
# 40359                  1  hello twitter friend marisol proud beauti smar...
# 18812                  5  new keralau voic deep concern right abus face ...
# 35780                  0  yeah bc im hot get degre kind big thing work p...
# 6072                   3  rt mkr purpos pick slightli unattract girl bes...
# 32363                  0  high school bulli murder last year person forg...
# 28975                  4       wym noth like ugli as femal refus compar one

# %% [markdown]
# ## Cleaned text from the tweets have been added in the data frame

# %% [markdown]
# ## Dealing with duplicate text in the data frame

# %%
data['Text'].duplicated().sum()
# Out:
# 1675

# %%
data['Cleaned_Text'].duplicated().sum()
# Out:
# 3041

# %%
data.drop_duplicates('Cleaned_Text',inplace = True)

# %% [markdown]
# ## Tokenization of words

# %%
data['words_list'] = data['Cleaned_Text'].apply(word_tokenize)
data
# Out:
#                                                     Text          Sentiment  \
# 0      In other words #katandandre, your food was cra...  not_cyberbullying
# 1      Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2      @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3      @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4      @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# ...                                                  ...                ...
# 47687  Black ppl aren't expected to do anything, depe...          ethnicity
# 47688  Turner did not withhold his disappointment. Tu...          ethnicity
# 47689  I swear to God. This dumb nigger bitch. I have...          ethnicity
# 47690  Yea fuck you RT @therealexel: IF YOURE A NIGGE...          ethnicity
# 47691  Bro. U gotta chill RT @CHILLShrammy: Dog FUCK ...          ethnicity
#
#        Sentiment_encoded                                       Cleaned_Text  \
# 0                      3                 word katandandr food crapilici mkr
# 1                      3  aussietv white mkr theblock imacelebrityau tod...
# 2                      3                     classi whore red velvet cupcak
# 3                      3  meh p thank head concern anoth angri dude twitter
# 4                      3  isi account pretend kurdish account like islam...
# ...                  ...                                                ...
# 47687                  1  black ppl expect anyth depend anyth yet free p...
# 47688                  1  turner withhold disappoint turner call court a...
# 47689                  1  swear god dumb nigger bitch got bleach hair re...
# 47690                  1  yea fuck rt your nigger fuck unfollow fuck dum...
# 47691                  1  bro u got ta chill rt dog fuck kp dumb nigger ...
#
#                                               words_list
# 0               [word, katandandr, food, crapilici, mkr]
# 1      [aussietv, white, mkr, theblock, imacelebritya...
# 2                   [classi, whore, red, velvet, cupcak]
# 3      [meh, p, thank, head, concern, anoth, angri, d...
# 4      [isi, account, pretend, kurdish, account, like...
# ...                                                  ...
# 47687  [black, ppl, expect, anyth, depend, anyth, yet...
# 47688  [turner, withhold, disappoint, turner, call, c...
# 47689  [swear, god, dumb, nigger, bitch, got, bleach,...
# 47690  [yea, fuck, rt, your, nigger, fuck, unfollow, ...
# 47691  [bro, u, got, ta, chill, rt, dog, fuck, kp, du...
#
# [44651 rows x 5 columns]

# %% [markdown]
# # VISUALIZATION OF THE DATA

# %%
length = []
for text in data.words_list:
    tweet_len = len(text)
    length.append(tweet_len)
data['length'] = length

# %%
def plot_wordcloud(cyberbullying_type):
    string = ""
    for i in data[data.Sentiment == cyberbullying_type].Cleaned_Text.values:
        string = string + " " + i.strip()
    custom_mask = np.array(Image.open('/content/twitter-logo-png-transparent.png'))
    mask_colors = ImageColorGenerator(custom_mask)
    wordcloud = WordCloud(background_color='white',max_words=200, max_font_size=256,
        random_state=42, width=custom_mask.shape[1],height=custom_mask.shape[0],
        mask = custom_mask,min_font_size = 10,color_func=mask_colors).generate(string)
    # plot the WordCloud image
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(cyberbullying_type)
    plt.show()
    del string

# %%
data.shape
# Out:
# (44651, 6)

# %%
data['length'].describe()
# Out:
# count    44651.000000
# mean        13.376251
# std          8.373548
# min          0.000000
# 25%          7.000000
# 50%         12.000000
# 75%         19.000000
# max        384.000000
# Name: length, dtype: float64

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x='length', data=data, color='red')
# Out:
# <Axes: xlabel='length'>

# %%
plt.figure(figsize=(20,12))
ax = sns.countplot(x='length', data=data, palette='rocket_r')

# %% [markdown]
# ## Splitting data based on sentiment for data exploration

# %%
notcyber_bullying_type = data[data['Sentiment']=='not_cyberbullying']
gender_type = data[data['Sentiment']=='gender']
religion_type = data[data['Sentiment']=='religion']
other_cyberbullying_type = data[data['Sentiment']=='other_cyberbullying']
age_type = data[data['Sentiment']=='age']
ethnicity_type = data[data['Sentiment']=='ethnicity']

# %% [markdown]
# ## GENDER BASED CYBER BULLYING

# %%
gender = Counter([item for sublist in gender_type['words_list'] for item in sublist])
top20_gender = pd.DataFrame(gender.most_common(20))
top20_gender.columns = ['Top Words','Count']
top20_gender.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_dba73_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dba73_row1_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_dba73_row2_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_dba73_row3_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_dba73_row4_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_dba73_row5_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_dba73_row6_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_dba73_row7_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_dba73_row8_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_dba73_row9_col1, #T_dba73_row10_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_dba73_row11_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_dba73_row12_col1, #T_dba73_row13_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_dba73_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_dba73_row15_col1, #T_dba73_row16_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_dba73_row17_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_dba73_row18_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_dba73_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_dba73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dba73_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_dba73_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dba73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dba73_row0_col0" class="data row0 col0" >joke</td>
#       <td id="T_dba73_row0_col1" class="data row0 col1" >5179</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dba73_row1_col0" class="data row1 col0" >rape</td>
#       <td id="T_dba73_row1_col1" class="data row1 col1" >4070</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dba73_row2_col0" class="data row2 col0" >gay</td>
#       <td id="T_dba73_row2_col1" class="data row2 col1" >3852</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dba73_row3_col0" class="data row3 col0" >call</td>
#       <td id="T_dba73_row3_col1" class="data row3 col1" >1401</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dba73_row4_col0" class="data row4 col0" >make</td>
#       <td id="T_dba73_row4_col1" class="data row4 col1" >1283</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dba73_row5_col0" class="data row5 col0" >rt</td>
#       <td id="T_dba73_row5_col1" class="data row5 col1" >1221</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dba73_row6_col0" class="data row6 col0" >woman</td>
#       <td id="T_dba73_row6_col1" class="data row6 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dba73_row7_col0" class="data row7 col0" >bitch</td>
#       <td id="T_dba73_row7_col1" class="data row7 col1" >1146</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dba73_row8_col0" class="data row8 col0" >femal</td>
#       <td id="T_dba73_row8_col1" class="data row8 col1" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dba73_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_dba73_row9_col1" class="data row9 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dba73_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_dba73_row10_col1" class="data row10 col1" >978</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dba73_row11_col0" class="data row11 col0" >sexist</td>
#       <td id="T_dba73_row11_col1" class="data row11 col1" >953</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dba73_row12_col0" class="data row12 col0" >funni</td>
#       <td id="T_dba73_row12_col1" class="data row12 col1" >662</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dba73_row13_col0" class="data row13 col0" >mkr</td>
#       <td id="T_dba73_row13_col1" class="data row13 col1" >659</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dba73_row14_col0" class="data row14 col0" >men</td>
#       <td id="T_dba73_row14_col1" class="data row14 col1" >614</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dba73_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_dba73_row15_col1" class="data row15 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dba73_row16_col0" class="data row16 col0" >think</td>
#       <td id="T_dba73_row16_col1" class="data row16 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dba73_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_dba73_row17_col1" class="data row17 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dba73_row18_col0" class="data row18 col0" >fuck</td>
#       <td id="T_dba73_row18_col1" class="data row18 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_dba73_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dba73_row19_col0" class="data row19 col0" >use</td>
#       <td id="T_dba73_row19_col1" class="data row19 col1" >441</td>
#     </tr>
#   </tbody>
# </table>

# %%
ig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_gender, y="Count", x="Top Words")
plt.title("Top 20 words in Gender Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Gender Cyberbullying')

# %%
plot_wordcloud('gender')

# %% [markdown]
# ## RELIGION BASED CYBERBULLYING

# %%
religion = Counter([item for sublist in religion_type['words_list'] for item in sublist])
top20_religion = pd.DataFrame(religion.most_common(20))
top20_religion.columns = ['Top Words','Count']
top20_religion.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_9b95d_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9b95d_row1_col1 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_9b95d_row2_col1 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_9b95d_row3_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_9b95d_row4_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_9b95d_row5_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_9b95d_row6_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_9b95d_row7_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_9b95d_row8_col1, #T_9b95d_row9_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_9b95d_row10_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_9b95d_row11_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_9b95d_row12_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_9b95d_row13_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_9b95d_row14_col1, #T_9b95d_row15_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_9b95d_row16_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_9b95d_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_9b95d_row18_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_9b95d_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_9b95d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b95d_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_9b95d_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b95d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b95d_row0_col0" class="data row0 col0" >muslim</td>
#       <td id="T_9b95d_row0_col1" class="data row0 col1" >4618</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b95d_row1_col0" class="data row1 col0" >idiot</td>
#       <td id="T_9b95d_row1_col1" class="data row1 col1" >3075</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b95d_row2_col0" class="data row2 col0" >islam</td>
#       <td id="T_9b95d_row2_col1" class="data row2 col1" >2440</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b95d_row3_col0" class="data row3 col0" >christian</td>
#       <td id="T_9b95d_row3_col1" class="data row3 col1" >2132</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b95d_row4_col0" class="data row4 col0" >u</td>
#       <td id="T_9b95d_row4_col1" class="data row4 col1" >1922</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b95d_row5_col0" class="data row5 col0" >terrorist</td>
#       <td id="T_9b95d_row5_col1" class="data row5 col1" >1378</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b95d_row6_col0" class="data row6 col0" >right</td>
#       <td id="T_9b95d_row6_col1" class="data row6 col1" >1289</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b95d_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_9b95d_row7_col1" class="data row7 col1" >1276</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b95d_row8_col0" class="data row8 col0" >support</td>
#       <td id="T_9b95d_row8_col1" class="data row8 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b95d_row9_col0" class="data row9 col0" >woman</td>
#       <td id="T_9b95d_row9_col1" class="data row9 col1" >1247</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b95d_row10_col0" class="data row10 col0" >terror</td>
#       <td id="T_9b95d_row10_col1" class="data row10 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9b95d_row11_col0" class="data row11 col0" >radic</td>
#       <td id="T_9b95d_row11_col1" class="data row11 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9b95d_row12_col0" class="data row12 col0" >peopl</td>
#       <td id="T_9b95d_row12_col1" class="data row12 col1" >1076</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9b95d_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_9b95d_row13_col1" class="data row13 col1" >812</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9b95d_row14_col0" class="data row14 col0" >amp</td>
#       <td id="T_9b95d_row14_col1" class="data row14 col1" >769</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9b95d_row15_col0" class="data row15 col0" >know</td>
#       <td id="T_9b95d_row15_col1" class="data row15 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9b95d_row16_col0" class="data row16 col0" >human</td>
#       <td id="T_9b95d_row16_col1" class="data row16 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9b95d_row17_col0" class="data row17 col0" >kill</td>
#       <td id="T_9b95d_row17_col1" class="data row17 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9b95d_row18_col0" class="data row18 col0" >hindu</td>
#       <td id="T_9b95d_row18_col1" class="data row18 col1" >688</td>
#     </tr>
#     <tr>
#       <th id="T_9b95d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9b95d_row19_col0" class="data row19 col0" >one</td>
#       <td id="T_9b95d_row19_col1" class="data row19 col1" >666</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_religion, y="Count", x="Top Words")
plt.title("Top 20 words in Religion Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Religion Cyberbullying')

# %%
plot_wordcloud('religion')

# %% [markdown]
# ## AGE BASED CYBER BULLYING

# %%
age = Counter([item for sublist in age_type['words_list'] for item in sublist])
top20_age = pd.DataFrame(age.most_common(20))
top20_age.columns = ['Top Words','Count']
top20_age.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c7de1_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c7de1_row1_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_c7de1_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_c7de1_row3_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_c7de1_row4_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_c7de1_row5_col1, #T_c7de1_row6_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_c7de1_row7_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_c7de1_row8_col1, #T_c7de1_row9_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_c7de1_row10_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_c7de1_row11_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_c7de1_row12_col1, #T_c7de1_row13_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_c7de1_row14_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_c7de1_row15_col1, #T_c7de1_row16_col1, #T_c7de1_row17_col1, #T_c7de1_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_c7de1_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c7de1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7de1_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_c7de1_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7de1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7de1_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_c7de1_row0_col1" class="data row0 col1" >8899</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7de1_row1_col0" class="data row1 col0" >school</td>
#       <td id="T_c7de1_row1_col1" class="data row1 col1" >8426</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7de1_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_c7de1_row2_col1" class="data row2 col1" >4861</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7de1_row3_col0" class="data row3 col0" >girl</td>
#       <td id="T_c7de1_row3_col1" class="data row3 col1" >4616</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7de1_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_c7de1_row4_col1" class="data row4 col1" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7de1_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_c7de1_row5_col1" class="data row5 col1" >1051</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7de1_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_c7de1_row6_col1" class="data row6 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7de1_row7_col0" class="data row7 col0" >peopl</td>
#       <td id="T_c7de1_row7_col1" class="data row7 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7de1_row8_col0" class="data row8 col0" >got</td>
#       <td id="T_c7de1_row8_col1" class="data row8 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7de1_row9_col0" class="data row9 col0" >kid</td>
#       <td id="T_c7de1_row9_col1" class="data row9 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7de1_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_c7de1_row10_col1" class="data row10 col1" >762</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7de1_row11_col0" class="data row11 col0" >middl</td>
#       <td id="T_c7de1_row11_col1" class="data row11 col1" >714</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7de1_row12_col0" class="data row12 col0" >friend</td>
#       <td id="T_c7de1_row12_col1" class="data row12 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7de1_row13_col0" class="data row13 col0" >im</td>
#       <td id="T_c7de1_row13_col1" class="data row13 col1" >625</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7de1_row14_col0" class="data row14 col0" >year</td>
#       <td id="T_c7de1_row14_col1" class="data row14 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7de1_row15_col0" class="data row15 col0" >go</td>
#       <td id="T_c7de1_row15_col1" class="data row15 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7de1_row16_col0" class="data row16 col0" >look</td>
#       <td id="T_c7de1_row16_col1" class="data row16 col1" >545</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7de1_row17_col0" class="data row17 col0" >amp</td>
#       <td id="T_c7de1_row17_col1" class="data row17 col1" >527</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7de1_row18_col0" class="data row18 col0" >know</td>
#       <td id="T_c7de1_row18_col1" class="data row18 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_c7de1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c7de1_row19_col0" class="data row19 col0" >u</td>
#       <td id="T_c7de1_row19_col1" class="data row19 col1" >477</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_age, y="Count", x="Top Words")
plt.title("Top 20 words in Age Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Age Cyberbullying')

# %%
plot_wordcloud('age')

# %% [markdown]
# ## ETHNICITY BASED CYBERBULLYING

# %%
ethnicity = Counter([item for sublist in ethnicity_type['words_list'] for item in sublist])
top20_ethnicity = pd.DataFrame(ethnicity.most_common(20))
top20_ethnicity.columns = ['Top Words','Count']
top20_ethnicity.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_ce0b5_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ce0b5_row1_col1 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_ce0b5_row2_col1 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_ce0b5_row3_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_ce0b5_row4_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_ce0b5_row5_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_ce0b5_row6_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_ce0b5_row7_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_ce0b5_row8_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_ce0b5_row9_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_ce0b5_row10_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_ce0b5_row11_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_ce0b5_row12_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_ce0b5_row13_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_ce0b5_row14_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_ce0b5_row15_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_ce0b5_row16_col1, #T_ce0b5_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_ce0b5_row18_col1, #T_ce0b5_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_ce0b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce0b5_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_ce0b5_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce0b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce0b5_row0_col0" class="data row0 col0" >fuck</td>
#       <td id="T_ce0b5_row0_col1" class="data row0 col1" >5892</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce0b5_row1_col0" class="data row1 col0" >nigger</td>
#       <td id="T_ce0b5_row1_col1" class="data row1 col1" >5456</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce0b5_row2_col0" class="data row2 col0" >dumb</td>
#       <td id="T_ce0b5_row2_col1" class="data row2 col1" >5003</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce0b5_row3_col0" class="data row3 col0" >as</td>
#       <td id="T_ce0b5_row3_col1" class="data row3 col1" >2241</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce0b5_row4_col0" class="data row4 col0" >black</td>
#       <td id="T_ce0b5_row4_col1" class="data row4 col1" >2134</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce0b5_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_ce0b5_row5_col1" class="data row5 col1" >2107</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce0b5_row6_col0" class="data row6 col0" >white</td>
#       <td id="T_ce0b5_row6_col1" class="data row6 col1" >1557</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce0b5_row7_col0" class="data row7 col0" >call</td>
#       <td id="T_ce0b5_row7_col1" class="data row7 col1" >1381</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce0b5_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_ce0b5_row8_col1" class="data row8 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce0b5_row9_col0" class="data row9 col0" >rt</td>
#       <td id="T_ce0b5_row9_col1" class="data row9 col1" >1166</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ce0b5_row10_col0" class="data row10 col0" >obama</td>
#       <td id="T_ce0b5_row10_col1" class="data row10 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ce0b5_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_ce0b5_row11_col1" class="data row11 col1" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ce0b5_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_ce0b5_row12_col1" class="data row12 col1" >1035</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ce0b5_row13_col0" class="data row13 col0" >bitch</td>
#       <td id="T_ce0b5_row13_col1" class="data row13 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ce0b5_row14_col0" class="data row14 col0" >ur</td>
#       <td id="T_ce0b5_row14_col1" class="data row14 col1" >987</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ce0b5_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_ce0b5_row15_col1" class="data row15 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ce0b5_row16_col0" class="data row16 col0" >first</td>
#       <td id="T_ce0b5_row16_col1" class="data row16 col1" >745</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ce0b5_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_ce0b5_row17_col1" class="data row17 col1" >740</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ce0b5_row18_col0" class="data row18 col0" >anyth</td>
#       <td id="T_ce0b5_row18_col1" class="data row18 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_ce0b5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ce0b5_row19_col0" class="data row19 col0" >racism</td>
#       <td id="T_ce0b5_row19_col1" class="data row19 col1" >689</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_ethnicity, y="Count", x="Top Words")
plt.title("Top 20 words in Ethnicity Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Ethnicity Cyberbullying')

# %%
plot_wordcloud('ethnicity')

# %% [markdown]
# ##  OTHER TYPES OF CYBERBULLYING

# %%
other_cyberbullying = Counter([item for sublist in other_cyberbullying_type['words_list'] for item in sublist])
top20_other_cyberbullying = pd.DataFrame(other_cyberbullying.most_common(20))
top20_other_cyberbullying.columns = ['Top Words','Count']
top20_other_cyberbullying.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_d70eb_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d70eb_row1_col1 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_d70eb_row2_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_d70eb_row3_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_d70eb_row4_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_d70eb_row5_col1 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_d70eb_row6_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_d70eb_row7_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_d70eb_row8_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_d70eb_row9_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_d70eb_row10_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_d70eb_row11_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_d70eb_row12_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_d70eb_row13_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_d70eb_row14_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_d70eb_row15_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_d70eb_row16_col1, #T_d70eb_row17_col1, #T_d70eb_row18_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d70eb_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_d70eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d70eb_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_d70eb_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d70eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d70eb_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_d70eb_row0_col1" class="data row0 col1" >882</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d70eb_row1_col0" class="data row1 col0" >rt</td>
#       <td id="T_d70eb_row1_col1" class="data row1 col1" >727</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d70eb_row2_col0" class="data row2 col0" >fuck</td>
#       <td id="T_d70eb_row2_col1" class="data row2 col1" >509</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d70eb_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_d70eb_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d70eb_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_d70eb_row4_col1" class="data row4 col1" >393</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d70eb_row5_col0" class="data row5 col0" >peopl</td>
#       <td id="T_d70eb_row5_col1" class="data row5 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d70eb_row6_col0" class="data row6 col0" >go</td>
#       <td id="T_d70eb_row6_col1" class="data row6 col1" >277</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d70eb_row7_col0" class="data row7 col0" >idiot</td>
#       <td id="T_d70eb_row7_col1" class="data row7 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d70eb_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_d70eb_row8_col1" class="data row8 col1" >241</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d70eb_row9_col0" class="data row9 col0" >think</td>
#       <td id="T_d70eb_row9_col1" class="data row9 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d70eb_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_d70eb_row10_col1" class="data row10 col1" >235</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d70eb_row11_col0" class="data row11 col0" >u</td>
#       <td id="T_d70eb_row11_col1" class="data row11 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d70eb_row12_col0" class="data row12 col0" >make</td>
#       <td id="T_d70eb_row12_col1" class="data row12 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d70eb_row13_col0" class="data row13 col0" >one</td>
#       <td id="T_d70eb_row13_col1" class="data row13 col1" >205</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d70eb_row14_col0" class="data row14 col0" >time</td>
#       <td id="T_d70eb_row14_col1" class="data row14 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d70eb_row15_col0" class="data row15 col0" >hate</td>
#       <td id="T_d70eb_row15_col1" class="data row15 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d70eb_row16_col0" class="data row16 col0" >want</td>
#       <td id="T_d70eb_row16_col1" class="data row16 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d70eb_row17_col0" class="data row17 col0" >thing</td>
#       <td id="T_d70eb_row17_col1" class="data row17 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d70eb_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_d70eb_row18_col1" class="data row18 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_d70eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d70eb_row19_col0" class="data row19 col0" >see</td>
#       <td id="T_d70eb_row19_col1" class="data row19 col1" >178</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_other_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Other Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Other Cyberbullying')

# %%
plot_wordcloud('other_cyberbullying')

# %% [markdown]
# ## TWEET WITHOUT CYBERBULLYING

# %%
not_cyberbullying = Counter([item for sublist in notcyber_bullying_type['words_list'] for item in sublist])
top20_not_cyberbullying = pd.DataFrame(not_cyberbullying.most_common(20))
top20_not_cyberbullying.columns = ['Top Words','Count']
top20_not_cyberbullying.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_da8a4_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_da8a4_row1_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_da8a4_row2_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_da8a4_row3_col1, #T_da8a4_row4_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_da8a4_row5_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_da8a4_row6_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_da8a4_row7_col1, #T_da8a4_row8_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_da8a4_row9_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_da8a4_row10_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_da8a4_row11_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_da8a4_row12_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_da8a4_row13_col1, #T_da8a4_row14_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_da8a4_row15_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_da8a4_row16_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_da8a4_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_da8a4_row18_col1, #T_da8a4_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_da8a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da8a4_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_da8a4_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da8a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da8a4_row0_col0" class="data row0 col0" >mkr</td>
#       <td id="T_da8a4_row0_col1" class="data row0 col1" >1674</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da8a4_row1_col0" class="data row1 col0" >bulli</td>
#       <td id="T_da8a4_row1_col1" class="data row1 col1" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da8a4_row2_col0" class="data row2 col0" >rt</td>
#       <td id="T_da8a4_row2_col1" class="data row2 col1" >785</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da8a4_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_da8a4_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da8a4_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_da8a4_row4_col1" class="data row4 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da8a4_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_da8a4_row5_col1" class="data row5 col1" >394</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_da8a4_row6_col0" class="data row6 col0" >school</td>
#       <td id="T_da8a4_row6_col1" class="data row6 col1" >374</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_da8a4_row7_col0" class="data row7 col0" >kat</td>
#       <td id="T_da8a4_row7_col1" class="data row7 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_da8a4_row8_col0" class="data row8 col0" >would</td>
#       <td id="T_da8a4_row8_col1" class="data row8 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_da8a4_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_da8a4_row9_col1" class="data row9 col1" >272</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_da8a4_row10_col0" class="data row10 col0" >one</td>
#       <td id="T_da8a4_row10_col1" class="data row10 col1" >264</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_da8a4_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_da8a4_row11_col1" class="data row11 col1" >258</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_da8a4_row12_col0" class="data row12 col0" >think</td>
#       <td id="T_da8a4_row12_col1" class="data row12 col1" >242</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_da8a4_row13_col0" class="data row13 col0" >u</td>
#       <td id="T_da8a4_row13_col1" class="data row13 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_da8a4_row14_col0" class="data row14 col0" >know</td>
#       <td id="T_da8a4_row14_col1" class="data row14 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_da8a4_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_da8a4_row15_col1" class="data row15 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_da8a4_row16_col0" class="data row16 col0" >make</td>
#       <td id="T_da8a4_row16_col1" class="data row16 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_da8a4_row17_col0" class="data row17 col0" >love</td>
#       <td id="T_da8a4_row17_col1" class="data row17 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_da8a4_row18_col0" class="data row18 col0" >andr</td>
#       <td id="T_da8a4_row18_col1" class="data row18 col1" >194</td>
#     </tr>
#     <tr>
#       <th id="T_da8a4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_da8a4_row19_col0" class="data row19 col0" >need</td>
#       <td id="T_da8a4_row19_col1" class="data row19 col1" >191</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_not_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Not Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Not Cyberbullying')

# %%
plot_wordcloud('not_cyberbullying')

# %%
data.head(10)
# Out:
#                                                 Text          Sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# 5  @Raja5aab @Quickieleaks Yes, the test of god i...  not_cyberbullying
# 6  Itu sekolah ya bukan tempat bully! Ga jauh kay...  not_cyberbullying
# 7  Karma. I hope it bites Kat on the butt. She is...  not_cyberbullying
# 8       @stockputout everything but mostly my priest  not_cyberbullying
# 9  Rebecca Black Drops Out of School Due to Bully...  not_cyberbullying
#
#    Sentiment_encoded                                       Cleaned_Text  \
# 0                  3                 word katandandr food crapilici mkr
# 1                  3  aussietv white mkr theblock imacelebrityau tod...
# 2                  3                     classi whore red velvet cupcak
# 3                  3  meh p thank head concern anoth angri dude twitter
# 4                  3  isi account pretend kurdish account like islam...
# 5                  3  ye test god good bad indiffer weird whatev pro...
# 6                  3  itu sekolah ya bukan tempat bulli ga jauh kaya...
# 7                  3                 karma hope bite kat butt nasti mkr
# 8                  3                              everyth mostli priest
# 9                  3                rebecca black drop school due bulli
#
#                                           words_list  length
# 0           [word, katandandr, food, crapilici, mkr]       5
# 1  [aussietv, white, mkr, theblock, imacelebritya...      11
# 2               [classi, whore, red, velvet, cupcak]       5
# 3  [meh, p, thank, head, concern, anoth, angri, d...       9
# 4  [isi, account, pretend, kurdish, account, like...       8
# 5  [ye, test, god, good, bad, indiffer, weird, wh...      11
# 6  [itu, sekolah, ya, bukan, tempat, bulli, ga, j...      10
# 7         [karma, hope, bite, kat, butt, nasti, mkr]       7
# 8                          [everyth, mostli, priest]       3
# 9         [rebecca, black, drop, school, due, bulli]       6

# %%
data.Sentiment.value_counts()
# Out:
# religion               7952
# age                    7884
# ethnicity              7770
# not_cyberbullying      7646
# gender                 7620
# other_cyberbullying    5779
# Name: Sentiment, dtype: int64

# %%
sentiments = ['religion','age','ethnicity','gender','not_cyberbullying','other_cyberbullying']

# %%
data.head()
# Out:
#                                                 Text          Sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    Sentiment_encoded                                       Cleaned_Text  \
# 0                  3                 word katandandr food crapilici mkr
# 1                  3  aussietv white mkr theblock imacelebrityau tod...
# 2                  3                     classi whore red velvet cupcak
# 3                  3  meh p thank head concern anoth angri dude twitter
# 4                  3  isi account pretend kurdish account like islam...
#
#                                           words_list  length
# 0           [word, katandandr, food, crapilici, mkr]       5
# 1  [aussietv, white, mkr, theblock, imacelebritya...      11
# 2               [classi, whore, red, velvet, cupcak]       5
# 3  [meh, p, thank, head, concern, anoth, angri, d...       9
# 4  [isi, account, pretend, kurdish, account, like...       8

# %%
data.columns
# Out:
# Index(['Text', 'Sentiment', 'Sentiment_encoded', 'Cleaned_Text', 'words_list',
#        'length'],
#       dtype='object')

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# # Splitting the data into train and test sets

# %%
X, Y = data['Cleaned_Text'], data['Sentiment_encoded']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, stratify=Y, random_state= 25)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (35720,) (8931,) (35720,) (8931,)

# %% [markdown]
# ## tf-idf vectorization

# %%
tf_idf = TfidfVectorizer()
X_train_tf = tf_idf.fit_transform(X_train)
X_test_tf = tf_idf.transform(X_test)
print(X_train_tf.shape)
print(X_test_tf.shape)
# Out:
# (35720, 31895)
# (8931, 31895)

# %%
X_train_tf
# Out:
# <35720x31895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 440320 stored elements in Compressed Sparse Row format>

# %%
X_test_tf
# Out:
# <8931x31895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 105165 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Trying different ML models

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train_tf, Y_train)
# Out:
# LogisticRegression()

# %%
log_cv_score = cross_val_score(log_reg, X_train_tf, Y_train, cv=5, scoring= 'f1_macro', n_jobs=-1)

# %%
mean_log_cv = np.mean(log_cv_score)
mean_log_cv
# Out:
# 0.8251150954823713

# %%
ypred = log_reg.predict(X_test_tf)
print(log_reg.score(X_test_tf, Y_test))
# Out:
# 0.841563094838204

# %% [markdown]
# ## Support Vector Classifier

# %%
lin_svc = LinearSVC()

# %%
lin_svc_cv_score = cross_val_score(lin_svc,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_lin_svc_cv = np.mean(lin_svc_cv_score)
mean_lin_svc_cv
# Out:
# 0.8227953965536946

# %% [markdown]
# ## Naive Bayes Classifier

# %%
multiNB = MultinomialNB()

# %%
multiNB_cv_score = cross_val_score(multiNB,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_multiNB_cv = np.mean(multiNB_cv_score)
mean_multiNB_cv
# Out:
# 0.6741382100970938

# %% [markdown]
# ## Decison Tree Classifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree_cv_score = cross_val_score(dtree,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_dtree_cv = np.mean(dtree_cv_score)
mean_dtree_cv
# Out:
# 0.809555503195597

# %% [markdown]
# ## RandomForest Classifier

# %%
rand_forest = RandomForestClassifier()

# %%
rand_forest_cv_score = cross_val_score(rand_forest,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_rand_forest_cv = np.mean(rand_forest_cv_score)
mean_rand_forest_cv
# Out:
# 0.8297682210897523

# %% [markdown]
# ## Adaboost Classifier

# %%
adab = AdaBoostClassifier()

# %%
adab_cv_score = cross_val_score(adab,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_adab_cv = np.mean(adab_cv_score) 
mean_adab_cv
# Out:
# 0.7562555859747552

# %% [markdown]
# ## By trying different models we can see logistic regression, svm and random forest
# ## classifier performed similarly, so among these we will go with svm model as it is
# ## more generalised and light
# ## Fine Tuning Support Vector Classifier

# %%
svc1 = LinearSVC()
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10],
'loss':['hinge','squared_hinge'],
'fit_intercept':[True,False]}
grid_search = GridSearchCV(svc1,param_grid,cv=5,scoring='f1_macro',n_jobs=-1,verbose=0,return_train_score=True)
grid_search.fit(X_train_tf,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'fit_intercept': [True, False],
#                          'loss': ['hinge', 'squared_hinge']},
#              return_train_score=True, scoring='f1_macro')

# %%
grid_search.best_estimator_
# Out:
# LinearSVC(C=1, loss='hinge')

# %%
grid_search.best_score_
# Out:
# 0.8271200193542588

# %% [markdown]
# # MODEL EVALUATION

# %%
lin_svc.fit(X_train_tf, Y_train)
y_pred = lin_svc.predict(X_test_tf)

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize= (10,7), fontsize = 14):
    df_cm = pd.DataFrame(confusion_matrix, index =class_names, columns = class_names)
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot = True, fmt = 'd')
    except ValueError:
        raise ValueError('Confusion matrix values must be integer.')
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Preiction')

# %%
cm = confusion_matrix(Y_test, y_pred)
print_confusion_matrix(cm, sentiments)

# %%
print('Classification Report\n', classification_report(Y_test, y_pred, target_names=sentiments))
# Out:
# Classification Report
#                       precision    recall  f1-score   support
#
#            religion       0.92      0.97      0.95      1577
#                 age       0.96      0.98      0.97      1554
#           ethnicity       0.90      0.84      0.87      1524
#              gender       0.63      0.61      0.62      1529
#   not_cyberbullying       0.58      0.59      0.59      1156
# other_cyberbullying       0.95      0.96      0.95      1591
#
#            accuracy                           0.84      8931
#           macro avg       0.82      0.83      0.82      8931
#        weighted avg       0.84      0.84      0.84      8931

# %% [markdown]
# # Saving model

# %%
#pickle.dump(tf_idf, open('vectorizer.pkl', 'wb'))
#pickle.dump(lin_svc, open('model.pkl', 'wb'))
